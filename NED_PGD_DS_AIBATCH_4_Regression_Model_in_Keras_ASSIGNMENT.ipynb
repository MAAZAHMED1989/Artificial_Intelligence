# %% [markdown]
# <a href="https://colab.research.google.com/github/MAAZAHMED306/Artificial_Intelligence/blob/master/NED_PGD_DS_AIBATCH_4_Regression_Model_in_Keras_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Build a Regression Model in Keras

# %% [markdown]
# ### Step-By-Step Assignment Instructions

# %% [markdown]
# 1. Assignment Topic:
#
# In this project, you will build a regression model using the Keras library to model the same data about concrete compressive strength that we used in labs 3.

# %% [markdown]
# 2. Concrete Data:
#
# For your convenience, the data can be found here again: https://cocl.us/concrete_data. To recap, the predictors in the data of concrete strength include: Cement, Blast Furnace Slag, Fly Ash, Water, Superplasticizer, Coarse Aggregate, Fine Aggregate.

# %% [markdown]
# 3. Assignment Instructions:

# %% [markdown]
# ## A. Build a baseline model
#
# 1.   List item
# 2.   List item
#
#
#
# Use the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Use the adam optimizer and the mean squared error as the loss function.
#
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_splithelper function from Scikit-learn.
#
# 2. Train the model on the training data using 50 epochs.
#
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# 5. Report the mean and the standard deviation of the mean squared errors.
#
# Submit your Jupyter Notebook with your code and comments.

# %% [markdown]
# Import the pandas, the numpy, the keras libraries and the packages from the keras library:

# %%
import pandas as pd
import numpy as np
import keras
import sklearn
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# Download the data file:

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head(10)
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
# 5   266.0               114.0      0.0  228.0               0.0
# 6   380.0                95.0      0.0  228.0               0.0
# 7   380.0                95.0      0.0  228.0               0.0
# 8   266.0               114.0      0.0  228.0               0.0
# 9   475.0                 0.0      0.0  228.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30
# 5             932.0           670.0   90     47.03
# 6             932.0           594.0  365     43.70
# 7             932.0           594.0   28     36.45
# 8             932.0           670.0   28     45.85
# 9             932.0           594.0   28     39.29

# %% [markdown]
# Check how many point in the data frame, missing values, and genetal information:

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# Split the data into target (strength) and (predictors):

# %%
concrete_data_columns = concrete_data.columns

# %%
target = concrete_data['Strength']
target.head(10)
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# 5    47.03
# 6    43.70
# 7    36.45
# 8    45.85
# 9    39.29
# Name: Strength, dtype: float64

# %%
predictors = concrete_data.iloc[:, :-1]
predictors.head(10)
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
# 5   266.0               114.0      0.0  228.0               0.0
# 6   380.0                95.0      0.0  228.0               0.0
# 7   380.0                95.0      0.0  228.0               0.0
# 8   266.0               114.0      0.0  228.0               0.0
# 9   475.0                 0.0      0.0  228.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360
# 5             932.0           670.0   90
# 6             932.0           594.0  365
# 7             932.0           594.0   28
# 8             932.0           670.0   28
# 9             932.0           594.0   28

# %% [markdown]
# Create a function that defines our regression model for us so that we can conveniently call it to create our model:
#  - One hidden layer of 10 nodes, and a ReLU activation function
#  - Use the adam optimizer and the mean squared error as the loss function.

# %%
#num of inputs = num of predictors colums
n_cols = predictors.shape[1]
def regression_model():
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))

    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# Build the model:

# %%
model = regression_model()

# %% [markdown]
# Train and test the model at the same time using the fit-method. We will leave out 30% of the data for validation and we will train the model for 50 epochs.

# %%
list_of_mean_squared_error = []
for cycle in range(50):
    #Randomly split the data into a training set (70%) and a test set (30%):
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3)
    #Train and test the model at the same time
    res = model.fit(X_train, y_train, epochs=50, verbose=0, validation_data=(X_test, y_test))
    #Find mean_squared_error as last value in history.
    mean_squared_error = res.history['val_loss'][-1]
    #Add value of mean_squared_error for every cycle in list.
    list_of_mean_squared_error.append(mean_squared_error)
    print('Cycle #{}: mean_squared_error {}'.format(cycle+1, mean_squared_error))
# Out:
# Cycle #1: mean_squared_error 244.53424072265625
# Cycle #2: mean_squared_error 153.09646606445312
# Cycle #3: mean_squared_error 153.92376708984375
# Cycle #4: mean_squared_error 141.56202697753906
# Cycle #5: mean_squared_error 103.46117401123047
# Cycle #6: mean_squared_error 119.00355529785156
# Cycle #7: mean_squared_error 121.41255950927734
# Cycle #8: mean_squared_error 84.66602325439453
# Cycle #9: mean_squared_error 79.92535400390625
# Cycle #10: mean_squared_error 53.5482292175293
# Cycle #11: mean_squared_error 62.025657653808594
# Cycle #12: mean_squared_error 63.686527252197266
# Cycle #13: mean_squared_error 54.01896286010742
# Cycle #14: mean_squared_error 45.82975387573242
# Cycle #15: mean_squared_error 51.65364456176758
# Cycle #16: mean_squared_error 53.12458801269531
# Cycle #17: mean_squared_error 54.55341720581055
# Cycle #18: mean_squared_error 48.58855056762695
# Cycle #19: mean_squared_error 56.60730743408203
# Cycle #20: mean_squared_error 52.04685974121094
# Cycle #21: mean_squared_error 51.93294143676758
# Cycle #22: mean_squared_error 46.791412353515625
# Cycle #23: mean_squared_error 49.602577209472656
# Cycle #24: mean_squared_error 50.51536178588867
# Cycle #25: mean_squared_error 43.97316360473633
# Cycle #26: mean_squared_error 66.9652328491211
# Cycle #27: mean_squared_error 43.92584991455078
# Cycle #28: mean_squared_error 44.84198760986328
# Cycle #29: mean_squared_error 43.26088333129883
# Cycle #30: mean_squared_error 45.301029205322266
# Cycle #31: mean_squared_error 57.709068298339844
# Cycle #32: mean_squared_error 51.67732620239258
# Cycle #33: mean_squared_error 44.27910232543945
# Cycle #34: mean_squared_error 47.98615646362305
# Cycle #35: mean_squared_error 45.69449996948242
# Cycle #36: mean_squared_error 54.029441833496094
# Cycle #37: mean_squared_error 46.73407745361328
# Cycle #38: mean_squared_error 51.05939483642578
# Cycle #39: mean_squared_error 44.131290435791016
# Cycle #40: mean_squared_error 46.777198791503906
# Cycle #41: mean_squared_error 66.0832748413086
# Cycle #42: mean_squared_error 58.0909309387207
# Cycle #43: mean_squared_error 48.86662673950195
# Cycle #44: mean_squared_error 47.889404296875
# Cycle #45: mean_squared_error 48.6424674987793
# Cycle #46: mean_squared_error 44.5372314453125
# Cycle #47: mean_squared_error 42.812225341796875
# Cycle #48: mean_squared_error 47.322715759277344
# Cycle #49: mean_squared_error 45.87240219116211
# Cycle #50: mean_squared_error 42.21190643310547

# %% [markdown]
# Find the mean and the standard deviation of the mean squared errors:

# %%
print('The mean of the mean squared errors: {}'.format(np.mean(list_of_mean_squared_error)))
print('The standard deviation of the mean squared errors: {}'.format(np.std(list_of_mean_squared_error)))
# Out:
# The mean of the mean squared errors: 65.3357169342041
# The standard deviation of the mean squared errors: 38.03493924414302

# %% [markdown]
# ## B. Normalize the data
#
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.
#
# How does the mean of the mean squared errors compare to that from Step A?

# %% [markdown]
# Normalize the data by substracting the mean and dividing by the standard deviation:

# %%
predictors_norm = (predictors - predictors.mean())/predictors.std()
predictors_norm.head(10)
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
# 5 -0.145138            0.464818 -0.846733  2.174405         -1.038638
# 6  0.945704            0.244603 -0.846733  2.174405         -1.038638
# 7  0.945704            0.244603 -0.846733  2.174405         -1.038638
# 8 -0.145138            0.464818 -0.846733  2.174405         -1.038638
# 9  1.854740           -0.856472 -0.846733  2.174405         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069
# 5         -0.526262       -1.291914  0.701883
# 6         -0.526262       -2.239829  5.055221
# 7         -0.526262       -2.239829 -0.279597
# 8         -0.526262       -1.291914 -0.279597
# 9         -0.526262       -2.239829 -0.279597

# %% [markdown]
# Build the model:

# %%
n_cols = predictors_norm.shape[1]
def regression_model2():
    model2 = Sequential()
    model2.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model2.add(Dense(1))

    model2.compile(optimizer='adam', loss='mean_squared_error')
    return model2

model2 = regression_model2()

# %% [markdown]
# Train and test the model at the same time using the fit-method. We will leave out 30% of the data for validation and we will train the model for 50 epochs. **And use predictors_norm instead of predictors.**

# %%
list_of_mean_squared_error = []
for cycle in range(50):
    #Randomly split the data into a training set (70%) and a test set (30%):
    X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3)
    #Train and test the model at the same time
    res = model2.fit(X_train, y_train, epochs=50, verbose=0, validation_data=(X_test, y_test))
    #Find mean_squared_error as last value in history.
    mean_squared_error = res.history['val_loss'][-1]
    #Add value of mean_squared_error for every cycle in list.
    list_of_mean_squared_error.append(mean_squared_error)
    print('Cycle #{}: mean_squared_error {}'.format(cycle+1, mean_squared_error))
# Out:
# Cycle #1: mean_squared_error 260.5743408203125
# Cycle #2: mean_squared_error 153.8527069091797
# Cycle #3: mean_squared_error 102.99192810058594
# Cycle #4: mean_squared_error 99.06615447998047
# Cycle #5: mean_squared_error 81.75801849365234
# Cycle #6: mean_squared_error 64.30499267578125
# Cycle #7: mean_squared_error 54.39258575439453
# Cycle #8: mean_squared_error 50.46792984008789
# Cycle #9: mean_squared_error 42.30585861206055
# Cycle #10: mean_squared_error 46.171382904052734
# Cycle #11: mean_squared_error 36.572898864746094
# Cycle #12: mean_squared_error 39.21671676635742
# Cycle #13: mean_squared_error 37.23049545288086
# Cycle #14: mean_squared_error 44.5635871887207
# Cycle #15: mean_squared_error 35.46001052856445
# Cycle #16: mean_squared_error 39.21351623535156
# Cycle #17: mean_squared_error 39.959197998046875
# Cycle #18: mean_squared_error 36.832420349121094
# Cycle #19: mean_squared_error 35.651634216308594
# Cycle #20: mean_squared_error 35.80466079711914
# Cycle #21: mean_squared_error 40.255836486816406
# Cycle #22: mean_squared_error 39.91837692260742
# Cycle #23: mean_squared_error 42.225852966308594
# Cycle #24: mean_squared_error 36.53618240356445
# Cycle #25: mean_squared_error 39.066654205322266
# Cycle #26: mean_squared_error 32.69062805175781
# Cycle #27: mean_squared_error 40.70261764526367
# Cycle #28: mean_squared_error 32.820186614990234
# Cycle #29: mean_squared_error 37.5609016418457
# Cycle #30: mean_squared_error 39.28501892089844
# Cycle #31: mean_squared_error 39.454654693603516
# Cycle #32: mean_squared_error 34.73630142211914
# Cycle #33: mean_squared_error 39.96763610839844
# Cycle #34: mean_squared_error 37.115230560302734
# Cycle #35: mean_squared_error 33.708412170410156
# Cycle #36: mean_squared_error 35.212528228759766
# Cycle #37: mean_squared_error 41.35595703125
# Cycle #38: mean_squared_error 30.969799041748047
# Cycle #39: mean_squared_error 30.980731964111328
# Cycle #40: mean_squared_error 36.08312225341797
# Cycle #41: mean_squared_error 32.999732971191406
# Cycle #42: mean_squared_error 41.29525375366211
# Cycle #43: mean_squared_error 37.05336380004883
# Cycle #44: mean_squared_error 35.27925491333008
# Cycle #45: mean_squared_error 33.93545913696289
# Cycle #46: mean_squared_error 32.213966369628906
# Cycle #47: mean_squared_error 34.40135955810547
# Cycle #48: mean_squared_error 35.909507751464844
# Cycle #49: mean_squared_error 31.538284301757812
# Cycle #50: mean_squared_error 35.52714920043945

# %% [markdown]
# Find the mean and the standard deviation of the mean squared errors:

# %%
print('The mean of the mean squared errors: {}'.format(np.mean(list_of_mean_squared_error)))
print('The standard deviation of the mean squared errors: {}'.format(np.std(list_of_mean_squared_error)))
# Out:
# The mean of the mean squared errors: 48.543819961547854
# The standard deviation of the mean squared errors: 37.13572796201851

# %% [markdown]
# **The mean and the standard deviation of the mean squared errors in case A is less than in case B. But the difference is tiny. And in my opinion it's not a very good idea to compare result of two poor neural networks with one hidden layer only. Data normalization does not help a lot. Error is huge for both cases: A and B.**

# %% [markdown]
# ## C. Increate the number of epochs
#
# Repeat Part B but use 100 epochs this time for training.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %% [markdown]
# Train and test the model at the same time using the fit-method. We will leave out 30% of the data (data after normalization) for validation and we will train the model **for 100 epochs instead of 50 epochs**.

# %% [markdown]
# Build the model:

# %%
def regression_model3():
    model3 = Sequential()
    model3.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model3.add(Dense(1))

    model3.compile(optimizer='adam', loss='mean_squared_error')
    return model3

model3 = regression_model3()

# %%
list_of_mean_squared_error = []
for cycle in range(50):
    #Randomly split the data into a training set (70%) and a test set (30%):
    X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3)
    #Train and test the model at the same time
    res = model3.fit(X_train, y_train, epochs=100, verbose=0, validation_data=(X_test, y_test))
    #Find mean_squared_error as last value in history.
    mean_squared_error = res.history['val_loss'][-1]
    #Add value of mean_squared_error for every cycle in list.
    list_of_mean_squared_error.append(mean_squared_error)
    print('Cycle #{}: mean_squared_error {}'.format(cycle+1, mean_squared_error))
# Out:
# Cycle #1: mean_squared_error 177.9770965576172
# Cycle #2: mean_squared_error 93.54911041259766
# Cycle #3: mean_squared_error 55.03505325317383
# Cycle #4: mean_squared_error 50.509918212890625
# Cycle #5: mean_squared_error 35.91938400268555
# Cycle #6: mean_squared_error 39.114990234375
# Cycle #7: mean_squared_error 42.267452239990234
# Cycle #8: mean_squared_error 34.56583023071289
# Cycle #9: mean_squared_error 40.30400085449219
# Cycle #10: mean_squared_error 35.68765640258789
# Cycle #11: mean_squared_error 38.8093376159668
# Cycle #12: mean_squared_error 29.535118103027344
# Cycle #13: mean_squared_error 36.010677337646484
# Cycle #14: mean_squared_error 42.108428955078125
# Cycle #15: mean_squared_error 35.74563980102539
# Cycle #16: mean_squared_error 30.327735900878906
# Cycle #17: mean_squared_error 35.418365478515625
# Cycle #18: mean_squared_error 33.720638275146484
# Cycle #19: mean_squared_error 32.95323944091797
# Cycle #20: mean_squared_error 37.54494857788086
# Cycle #21: mean_squared_error 32.96823501586914
# Cycle #22: mean_squared_error 30.445024490356445
# Cycle #23: mean_squared_error 30.10230255126953
# Cycle #24: mean_squared_error 33.49065017700195
# Cycle #25: mean_squared_error 33.476585388183594
# Cycle #26: mean_squared_error 28.998245239257812
# Cycle #27: mean_squared_error 31.12627601623535
# Cycle #28: mean_squared_error 32.71781921386719
# Cycle #29: mean_squared_error 31.121238708496094
# Cycle #30: mean_squared_error 32.94668197631836
# Cycle #31: mean_squared_error 30.577524185180664
# Cycle #32: mean_squared_error 32.131752014160156
# Cycle #33: mean_squared_error 28.388826370239258
# Cycle #34: mean_squared_error 27.222993850708008
# Cycle #35: mean_squared_error 33.081722259521484
# Cycle #36: mean_squared_error 29.434999465942383
# Cycle #37: mean_squared_error 25.57499885559082
# Cycle #38: mean_squared_error 28.63276481628418
# Cycle #39: mean_squared_error 27.615488052368164
# Cycle #40: mean_squared_error 31.280731201171875
# Cycle #41: mean_squared_error 25.932952880859375
# Cycle #42: mean_squared_error 29.487178802490234
# Cycle #43: mean_squared_error 25.25323486328125
# Cycle #44: mean_squared_error 26.86002540588379
# Cycle #45: mean_squared_error 31.7226505279541
# Cycle #46: mean_squared_error 30.48348617553711
# Cycle #47: mean_squared_error 26.99308204650879
# Cycle #48: mean_squared_error 28.590349197387695
# Cycle #49: mean_squared_error 31.366008758544922
# Cycle #50: mean_squared_error 27.51620101928711

# %% [markdown]
# Find the mean and the standard deviation of the mean squared errors:

# %%
print('The mean of the mean squared errors: {}'.format(np.mean(list_of_mean_squared_error)))
print('The standard deviation of the mean squared errors: {}'.format(np.std(list_of_mean_squared_error)))
# Out:
# The mean of the mean squared errors: 37.05289302825928
# The standard deviation of the mean squared errors: 22.585214980138044

# %% [markdown]
# **The mean and the standard deviation of the mean squared errors in case C is bigger than in case B. But in both cases error is huge. In my opinion it's not a very good idea to compare result of two poor neural networks with one hidden layer only. Number of epoch does not help.**

# %% [markdown]
# ## D. Increase the number of hidden layers
#
# Repeat part B but use a neural network with the following instead:
#
# - Three hidden layers, each of 10 nodes and ReLU activation function.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %% [markdown]
# Create a new model with **three hidden layers, each of 10 nodes and ReLU activation function.**

# %%
def regression_model4():
    model4 = Sequential()
    model4.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model4.add(Dense(10, activation='relu'))
    model4.add(Dense(10, activation='relu'))
    model4.add(Dense(1))

    model4.compile(optimizer='adam', loss='mean_squared_error')
    return model4

# %% [markdown]
# Build a new model with 3 hidden layers:

# %%
model4 = regression_model4()

# %% [markdown]
# Train and test the model at the same time using the fit-method. We will leave out 30% of the data (data after normalization) for validation and we will train the model for 50 epochs and use **three hidden layers, each of 10 nodes and ReLU activation function**.

# %%
list_of_mean_squared_error = []
for cycle in range(50):
    #Randomly split the data into a training set (70%) and a test set (30%):
    X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3)
    #Train and test the model at the same time
    res = model4.fit(X_train, y_train, epochs=50, verbose=0, validation_data=(X_test, y_test))
    #Find mean_squared_error as last value in history.
    mean_squared_error = res.history['val_loss'][-1]
    #Add value of mean_squared_error for every cycle in list.
    list_of_mean_squared_error.append(mean_squared_error)
    print('Cycle #{}: mean_squared_error {}'.format(cycle+1, mean_squared_error))
# Out:
# Cycle #1: mean_squared_error 138.1492919921875
# Cycle #2: mean_squared_error 112.12638092041016
# Cycle #3: mean_squared_error 126.11743927001953
# Cycle #4: mean_squared_error 108.00872039794922
# Cycle #5: mean_squared_error 79.93342590332031
# Cycle #6: mean_squared_error 46.01618576049805
# Cycle #7: mean_squared_error 41.40870666503906
# Cycle #8: mean_squared_error 42.379295349121094
# Cycle #9: mean_squared_error 45.027225494384766
# Cycle #10: mean_squared_error 38.33480453491211
# Cycle #11: mean_squared_error 39.646278381347656
# Cycle #12: mean_squared_error 38.821537017822266
# Cycle #13: mean_squared_error 34.9600715637207
# Cycle #14: mean_squared_error 37.67379379272461
# Cycle #15: mean_squared_error 33.490718841552734
# Cycle #16: mean_squared_error 32.98752975463867
# Cycle #17: mean_squared_error 29.8486385345459
# Cycle #18: mean_squared_error 36.006072998046875
# Cycle #19: mean_squared_error 26.325254440307617
# Cycle #20: mean_squared_error 26.957094192504883
# Cycle #21: mean_squared_error 26.423229217529297
# Cycle #22: mean_squared_error 32.009761810302734
# Cycle #23: mean_squared_error 29.612483978271484
# Cycle #24: mean_squared_error 29.319320678710938
# Cycle #25: mean_squared_error 24.511281967163086
# Cycle #26: mean_squared_error 27.450960159301758
# Cycle #27: mean_squared_error 22.271692276000977
# Cycle #28: mean_squared_error 23.700712203979492
# Cycle #29: mean_squared_error 27.586496353149414
# Cycle #30: mean_squared_error 24.21961212158203
# Cycle #31: mean_squared_error 24.505624771118164
# Cycle #32: mean_squared_error 26.683881759643555
# Cycle #33: mean_squared_error 17.94219207763672
# Cycle #34: mean_squared_error 20.65420150756836
# Cycle #35: mean_squared_error 23.8863468170166
# Cycle #36: mean_squared_error 26.53026008605957
# Cycle #37: mean_squared_error 21.783205032348633
# Cycle #38: mean_squared_error 23.0881290435791
# Cycle #39: mean_squared_error 25.047060012817383
# Cycle #40: mean_squared_error 26.46385383605957
# Cycle #41: mean_squared_error 21.754196166992188
# Cycle #42: mean_squared_error 18.752437591552734
# Cycle #43: mean_squared_error 27.327613830566406
# Cycle #44: mean_squared_error 20.396900177001953
# Cycle #45: mean_squared_error 21.054649353027344
# Cycle #46: mean_squared_error 24.91729736328125
# Cycle #47: mean_squared_error 23.358484268188477
# Cycle #48: mean_squared_error 22.119712829589844
# Cycle #49: mean_squared_error 23.63063621520996
# Cycle #50: mean_squared_error 25.089956283569336

# %% [markdown]
# Find the mean and the standard deviation of the mean squared errors:

# %%
print('The mean of the mean squared errors: {}'.format(np.mean(list_of_mean_squared_error)))
print('The standard deviation of the mean squared errors: {}'.format(np.std(list_of_mean_squared_error)))
# Out:
# The mean of the mean squared errors: 36.926213111877445
# The standard deviation of the mean squared errors: 26.932573802161944

# %% [markdown]
# **The mean and the standard deviation of the mean squared errors in case D is less than in case A, B and C. And it's the only case where error is not very big. It means additional layers in neural network are more important than other things. Also it proves the comparison between poor neural network with one hidden layer in previous cases is a bad idea. Result can be unpredictable.**
